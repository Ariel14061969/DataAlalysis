# %%
from json.decoder import NaN
from math import nan

import math
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
country_data=pd.read_csv('country_with_data.csv')
df= country_data
df.set_index('Country',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 192 entries, Afghanistan to Zimbabwe
# Data columns (total 32 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ISO2                                191 non-null    str
#  1   Continent                           192 non-null    str
#  2   flag_url                            190 non-null    str
#  3   gdp                                 185 non-null    float64
#  4   sex_ratio                           185 non-null    float64
#  5   surface_area                        184 non-null    float64
#  6   life_expectancy_male                181 non-null    float64
#  7   unemployment                        179 non-null    float64
#  8   homicide_rate                       167 non-null    float64
#  9   urban_population_growth             185 non-null    float64
#  10  secondary_school_enrollment_female  173 non-null    float64
#  11  employment_agriculture              176 non-null    float64
#  12  co2_emissions                       132 non-null    float64
#  13  forested_area                       182 non-null    float64
#  14  tourists                            178 non-null    float64
#  15  life_expectancy_female              181 non-null    float64
#  16  post_secondary_enrollment_female    155 non-null    float64
#  17  post_secondary_enrollment_male      155 non-null    float64
#  18  primary_school_enrollment_female    179 non-null    float64
#  19  infant_mortality                    179 non-null    float64
#  20  gdp_growth                          185 non-null    float64
#  21  population                          185 non-null    float64
#  22  urban_population                    185 non-null    float64
#  23  secondary_school_enrollment_male    173 non-null    float64
#  24  pop_growth                          185 non-null    float64
#  25  region                              185 non-null    str
#  26  pop_density                         185 non-null    float64
#  27  internet_users                      184 non-null    float64
#  28  gdp_per_capita                      185 non-null    float64
#  29  fertility                           181 non-null    float64
#  30  refugees                            174 non-null    float64
#  31  primary_school_enrollment_male      179 non-null    float64
# dtypes: float64(28), str(4)
# memory usage: 49.5+ KB

# %%
df.keys()
# Out:
# Index(['ISO2', 'Continent', 'flag_url', 'gdp', 'sex_ratio', 'surface_area',
#        'life_expectancy_male', 'unemployment', 'homicide_rate',
#        'urban_population_growth', 'secondary_school_enrollment_female',
#        'employment_agriculture', 'co2_emissions', 'forested_area', 'tourists',
#        'life_expectancy_female', 'post_secondary_enrollment_female',
#        'post_secondary_enrollment_male', 'primary_school_enrollment_female',
#        'infant_mortality', 'gdp_growth', 'population', 'urban_population',
#        'secondary_school_enrollment_male', 'pop_growth', 'region',
#        'pop_density', 'internet_users', 'gdp_per_capita', 'fertility',
#        'refugees', 'primary_school_enrollment_male'],
#       dtype='str')

# %%
df['rel']=df['sex_ratio']/df['population']
ax=sns.histplot(df['rel'].dropna() , bins = 30)
print(df['rel'].dropna())
df.loc['Angola','sex_ratio']
# Out:
# Country
# Afghanistan    0.002708
# Albania        0.036032
# Algeria        0.002328
# Andorra        1.328571
# Angola         0.002979
#                  ...
# Venezuela      0.003404
# Vietnam        0.001024
# Yemen          0.003403
# Zambia         0.005336
# Zimbabwe       0.006143
# Name: rel, Length: 185, dtype: float64
# np.float64(97.9)

# %%
df['urban_population']
# Out:
# Country
# Afghanistan    25.8
# Albania        61.2
# Algeria        73.2
# Andorra        88.0
# Angola         66.2
#                ...
# Venezuela      88.2
# Vietnam        36.6
# Yemen          37.3
# Zambia         44.1
# Zimbabwe       32.2
# Name: urban_population, Length: 192, dtype: float64

# %%
df.loc['United States']
# Out:
# ISO2                                                                                 US
# Continent                                                                 North America
# flag_url                              https://api-ninjas-data.s3.us-west-2.amazonaws...
# gdp                                                                          20580223.0
# sex_ratio                                                                          97.9
# surface_area                                                                  9833517.0
# life_expectancy_male                                                               76.3
# unemployment                                                                        3.9
# homicide_rate                                                                       5.0
# urban_population_growth                                                             0.9
# secondary_school_enrollment_female                                                 98.7
# employment_agriculture                                                              1.3
# co2_emissions                                                                    4761.3
# forested_area                                                                      33.9
# tourists                                                                        79746.0
# life_expectancy_female                                                             81.3
# post_secondary_enrollment_female                                                  102.0
# post_secondary_enrollment_male                                                     75.0
# primary_school_enrollment_female                                                  101.4
# infant_mortality                                                                    5.8
# gdp_growth                                                                          2.9
# population                                                                     331003.0
# urban_population                                                                   82.5
# secondary_school_enrollment_male                                                   99.2
# pop_growth                                                                          0.6
# region                                                                 Northern America
# pop_density                                                                        36.2
# internet_users                                                                     87.3
# gdp_per_capita                                                                  62917.9
# fertility                                                                           1.8
# refugees                                                                         1043.2
# primary_school_enrollment_male                                                    102.2
# co2_emissions_rel                                                              0.014384
# rel                                                                                97.9
# Name: United States, dtype: object

# %%
MyCountry = "Israel"
print (df.loc[MyCountry])
MyContinent = country_data.loc[MyCountry,'Continent']
MyRegion = country_data.loc[MyCountry,'region']
exclude_col = ["gdp","rel","population","surface_area"]


compareTo = 'Region'
if compareTo == 'World':
    df=country_data
    countries_of_interest = ['United States','China','Germany']
elif compareTo == 'Continent':
    df = country_data[country_data['Continent']==MyContinent]
    countries_of_interest = ['Japan','India','Iran']
elif compareTo == 'Region':
    df = country_data[country_data['region']==MyRegion]
    countries_of_interest = ['Lebanon','Jordan','Yemen']

DivideByPop = ['tourists','area','co2_emissions']
for col in df.keys():
    if col not in exclude_col and isinstance(df.loc[MyCountry,col],float):
        df['rel']=df[col]
        lb = col
        if col in DivideByPop:
            df['rel']= df['rel']/df['population']
            lb = lb + ' per capita'

        ax=sns.histplot(df['rel'].dropna() , bins = 30)

        plt.xlabel(lb)
        if df.loc[MyCountry,'rel']:
            max_count = max([bar.get_height() for bar in ax.containers[0]])
            plt.vlines(x=df.loc[MyCountry,'rel'], ymin=0, ymax=max_count, colors="red", linestyles="dashed", lw=2)
            plt.text(x=df.loc[MyCountry,'rel'], y=max_count * 0.75, s=f" {MyCountry}", color="red", rotation=0, va='top')
            for countryOfInterest in countries_of_interest:
                plt.vlines(x=df.loc[countryOfInterest,'rel'], ymin=0, ymax=max_count, colors="yellow", linestyles="dashed", lw=1)
                plt.text(x=df.loc[countryOfInterest,'rel'], y=max_count , s=f" {countryOfInterest}",  color="yellow", rotation=45, va='top')
            # Show the plot
            plt.show()
# Out:
# ISO2                                                                                 IL
# Continent                                                                          Asia
# flag_url                              https://api-ninjas-data.s3.us-west-2.amazonaws...
# gdp                                                                            370588.0
# sex_ratio                                                                          99.1
# surface_area                                                                    22072.0
# life_expectancy_male                                                               81.0
# unemployment                                                                        3.8
# homicide_rate                                                                       1.5
# urban_population_growth                                                             1.7
# secondary_school_enrollment_female                                                106.0
# employment_agriculture                                                              0.9
# co2_emissions                                                                      63.8
# forested_area                                                                       7.6
# tourists                                                                         4121.0
# life_expectancy_female                                                             84.3
# post_secondary_enrollment_female                                                   74.5
# post_secondary_enrollment_male                                                     52.8
# primary_school_enrollment_female                                                  105.4
# infant_mortality                                                                    2.7
# gdp_growth                                                                          3.4
# population                                                                       8656.0
# urban_population                                                                   92.5
# secondary_school_enrollment_male                                                  104.2
# pop_growth                                                                          1.6
# region                                                                     Western Asia
# pop_density                                                                       400.0
# internet_users                                                                     83.7
# gdp_per_capita                                                                  44214.9
# fertility                                                                           3.0
# refugees                                                                           55.1
# primary_school_enrollment_male                                                    104.4
# co2_emissions_rel                                                              0.007371
# rel                                                                                99.1
# Name: Israel, dtype: object
